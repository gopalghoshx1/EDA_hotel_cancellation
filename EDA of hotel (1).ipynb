# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
df=pd.read_csv('Downloads/hotel_bookings 2.csv')

# %% [markdown]
# # Exploratory Data Analysis and Cleaning

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
df['reservation_Month'] = pd.to_datetime(df['reservation_status_date']).dt.strftime('%B')

# %%
df['reservation_Month']
# Out:
# 0          January
# 1          January
# 2         February
# 3         February
# 4            March
#             ...
# 119385        June
# 119386        July
# 119387        July
# 119388        July
# 119389        July
# Name: reservation_Month, Length: 119390, dtype: object

# %%
df.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status reservation_Month
# count        119390        119390             119390            119390
# unique            3             4                  3                12
# top      No Deposit     Transient          Check-Out           October
# ...

# %%
for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
    print('-'*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(['company','agent'],axis=1, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df['adr'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df=df[df['adr']<5000]

# %%
df['adr'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# std         0.483167     106.903570           0.707462
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# std                   13.589966                   8.780321
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # Data Analytics and Visualization

# %%
cancel_perc=df['is_canceled'].value_counts(normalize=True)
cancel_perc
# Out:
# 0    0.628653
# 1    0.371347
# Name: is_canceled, dtype: float64

# %%
plt.figure(figsize=(3,5))
plt.title('reservation status count')
plt.bar(('Not canceled','canceled'),df['is_canceled'].value_counts(),width=0.7,edgecolor='k')
plt.show()

# %%
plt.figure(figsize= (8,5))
ax1=sns.countplot(x='hotel',hue='is_canceled', data = df ,palette ='Blues')
legend_labels,_ = ax1. get_legend_handles_labels()
ax1.legend(['Not canceled','canceled'],bbox_to_anchor=(1,1))
plt.title('Reservation status in different hotels',size=20)
plt.xlabel('Hotel', size=12)
plt.ylabel('Number of reservation',size=12)
plt.show()

# %%
resort_Hotel=df[df['hotel']=='Resort Hotel']
resort_Hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
city_Hotel = df[df['hotel']=='City Hotel']
city_Hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.582918
# 1    0.417082
# Name: is_canceled, dtype: float64

# %%
city_Hotel=(city_Hotel.groupby('reservation_status_date')[['adr']].mean())
resort_Hotel=(resort_Hotel.groupby('reservation_status_date')[['adr']].mean())

# %%
plt.figure(figsize=(15,6))
plt.plot( city_Hotel.index,city_Hotel['adr'], label='City_Hotel')
plt.plot(resort_Hotel.index,resort_Hotel['adr'], label='Resort_Hotel')
plt.title('Average Daily Rate in City and Resort Hotel',fontsize= 20)
plt.xlabel('Date', fontsize= 15)
plt.ylabel('Rate',fontsize= 15)
plt.legend(loc="upper left",fontsize=10)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='reservation_Month',hue='is_canceled', data = df ,palette ='Reds')
plt.title('Reservation status of every month', fontsize=18)
plt.legend(['Not canceled','canceled'], fontsize= 12)
plt.show()

# %%
canceled_record_df= df[df['is_canceled']==1].groupby('reservation_Month')[['adr']].sum().reset_index()
canceled_record_df
# Out:
#    reservation_Month        adr
# 0              April  399361.20
# 1             August  296665.40
# 2           December  329229.60
# 3           February  399081.98
# 4            January  532660.54
# 5               July  387597.85
# 6               June  468827.36
# 7              March  419319.79
# 8                May  343229.69
# 9           November  331389.62
# 10           October  384742.47
# 11         September  340233.39

# %%
plt.figure(figsize=(12,5))
sns.barplot('reservation_Month','adr', data = canceled_record_df)
plt.title('Canceled Reservation Rate status of every month', fontsize=18)
plt.show()

# %%
canceled= df[df['is_canceled']==1]
plt.figure(figsize=(14,8))
plt.title('Top 10 countrys of Cancelation', fontsize=15)
plt.pie(canceled['country'].value_counts()[:10], labels= canceled['country'].value_counts()[:10].index, autopct='%.2f')
plt.show()

# %%
nt_canceled = df[df['is_canceled']==0]
nt_cancel_df=nt_canceled[(nt_canceled['reservation_status_date'] > '2016') & (nt_canceled['reservation_status_date'] < '2017')]
cleared_nt_cancel_df =( nt_cancel_df.groupby('reservation_status_date')[['adr']].mean())


cancel_df=canceled[(canceled['reservation_status_date'] > '2016') & (canceled['reservation_status_date'] < '2017')]
cleared_cancel_df =(cancel_df.groupby('reservation_status_date')[['adr']].mean())

# %%
df['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: market_segment, dtype: float64

# %%
canceled['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: market_segment, dtype: float64

# %%
plt.figure(figsize=(15,5))
plt.plot(cleared_cancel_df.index,cleared_cancel_df['adr'])
plt.plot(cleared_nt_cancel_df.index, cleared_nt_cancel_df['adr'])
plt.title('Average Daily Rate of Canceled and Non Canceled Hotels', fontsize=20)
plt.xlabel('2016-01 To 2017-01',fontsize=15)
plt.ylabel('Rate',fontsize=15)
plt.legend(['canceled','Not canceled'], fontsize= 12)
plt.show()
